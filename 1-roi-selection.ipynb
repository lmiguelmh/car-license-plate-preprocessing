# %% [markdown]
# ### ROI Selection
# https://youtu.be/BXO8fdkvCWM

# %% [markdown]
# #### 1. Manual selection of ROI
# ![title](resources/Manual-ROI-scaled.png)

# %%
import cv2
from plate import roi

def click_and_crop(event, x, y, flags, original_image_points):
    original, image, points = original_image_points
    if event == cv2.EVENT_LBUTTONDOWN:
        points.append((x,y))
        if len(points) > 4:
            del points[0]

    image[:,:,:] = original[:,:,:]
    for point in points:
        cv2.circle(image, point, 4, color=(0, 255, 0), thickness=-1)

img_path = "D:\\projects\\car-license-plate-recognition\\doc\\problem\\placas\\280503\\P5280109.jpg"
points_path = img_path + ".pkz"

image = cv2.imread(img_path)
points = []
clone = image.copy()
cv2.namedWindow("image")
cv2.setMouseCallback("image", click_and_crop, (clone, image, points))
while True:
    cv2.imshow("image", image)
    key = cv2.waitKey(1) & 0xFF
 
    if key == ord("c") or key == ord("C"):
        points.clear()
        image[:,:,:] = clone[:,:,:]
    if key == ord("s") or key == ord("S"):
        roi.save(points_path, points, compress=False)
        break
    if key == ord("q") or key == ord("Q"):
        break

cv2.destroyAllWindows()

# %% [markdown]
# #### 2. Automatic selection of ROI

# %%
% matplotlib inline

import cv2
import os
import matplotlib.pyplot as plt
from plate import detect, segment, roi

def get_files(dir, ext):
    return [f for f in os.listdir(dir) if os.path.isfile(os.path.join(dir, f)) and f.endswith(ext)]

# directory = "D:\\projects\\car-license-plate-recognition\\doc\\problem\\placas\\141002\\"
directory = "D:\\projects\\car-license-plate-recognition\\doc\\problem\\placas\\040603\\"
files = get_files(directory, ".jpg")

# file = files[0]
for file in files:
    img_path = directory + file
    points_path = img_path + ".pkz"

    print()
    print(img_path)
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    coordinates = detect.get_plates_coordinates(img_path) 
    if len(coordinates) > 0:
        roi.save(points_path, coordinates[0], compress=False)
# Out:
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P1010001.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P1010001.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P1010002.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P1010002.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P1010003.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P1010003.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P1010004.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P1010004.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P1010005.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P1010005.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P1010006.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P1010006.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040007.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040007.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040008.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040008.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040009.jpg
# plate coordinates found for 'au'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040009.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040010.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040010.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040011.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040011.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040012.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040012.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040013.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040013.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040014.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040014.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040015.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040015.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040016.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040016.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040017.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040017.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040018.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040018.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040019.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040019.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040020.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040020.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040021.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040021.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040022.jpg
# plate coordinates found for 'us'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040022.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040023.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040023.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040024.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040024.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040025.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040025.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040026.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040026.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040027.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040027.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040028.jpg
# plate coordinates found for 'us'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040028.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040029.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040029.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040030.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040030.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040031.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040031.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040032.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040032.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040033.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040033.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040034.jpg
# plate coordinates found for 'us'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040034.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040035.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040035.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040036.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040036.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040037.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040037.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040038.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040038.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040039.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040039.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040040.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040040.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040041.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040041.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040042.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040042.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040043.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040043.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040044.jpg
# plate coordinates found for 'us'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040044.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040045.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040045.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040046.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040046.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040047.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040047.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040048.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040048.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040049.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040049.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040050.jpg
# plate coordinates found for 'us'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040050.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040051.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040051.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040052.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040052.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040053.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040053.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040054.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040054.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040055.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040055.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040056.jpg
# plate coordinates found using haar detector
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040056.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040057.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040057.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040058.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040058.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040059.jpg
# plate coordinates found for 'au'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040059.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040060.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040060.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040061.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040061.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040062.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040062.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040063.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040063.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040064.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040064.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040065.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040065.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040066.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040066.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040067.jpg
# plate coordinates not found
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040068.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040068.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040069.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040069.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040070.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040070.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040071.jpg
# plate coordinates found for 'us'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040071.jpg.pkz"
#
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040072.jpg
# plate coordinates found for 'eu'
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040072.jpg.pkz"

# %% [markdown]
# #### 3. Final: Semi-automatic selection of ROI for license plates

# %%
% matplotlib inline

import cv2
import os
import matplotlib.pyplot as plt
from plate import detect, segment, roi

def get_files(dir, ext):
    return [f for f in os.listdir(dir) if os.path.isfile(os.path.join(dir, f)) and f.endswith(ext)]

def click_and_crop(event, x, y, flags, original_image_points):
    original, image, points = original_image_points
    if event == cv2.EVENT_LBUTTONDOWN:
        points.append((x,y))
        if len(points) > 4:
            del points[0]

    image[:,:,:] = original[:,:,:]
    for point in points:
        cv2.circle(image, point, 4, color=(0, 255, 0), thickness=-1)

# directory = "D:\\projects\\car-license-plate-recognition\\doc\\problem\\placas\\141002\\"
directory = "D:\\projects\\car-license-plate-recognition\\doc\\problem\\placas\\040603\\"
files = get_files(directory, ".jpg")
files = ["P6040022.jpg"]

for file in files:
    img_path = directory + file
    points_path = img_path + ".pkz"

    print()
    print(img_path)
    img = cv2.imread(img_path)
    clone = img.copy()

    points = []
    if os.path.exists(points_path):
        points = roi.retrieve(points_path, decompress=False)

    cv2.namedWindow("image")
    cv2.setMouseCallback("image", click_and_crop, (clone, img, points))
    while True:
        cv2.imshow("image", img)
        key = cv2.waitKey(1) & 0xFF

        if key == ord("c") or key == ord("C"):
            points.clear()
            img[:,:,:] = clone[:,:,:]
        if key == ord("s") or key == ord("S"):
            roi.save(points_path, points, compress=False)
            break
        if key == ord("q") or key == ord("Q"):
            break

cv2.destroyAllWindows()
# Out:
# D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040022.jpg
# retrieving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040022.jpg.pkz"
# saving "D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040022.jpg.pkz"
