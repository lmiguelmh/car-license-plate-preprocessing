# %% [markdown]
# ### License Plate Detection using HAAR cascade classifiers

# %%
% matplotlib inline

import matplotlib.pyplot as plt
import cv2
from plate import detect

# license plate is detected
img_path = "D:\\projects\\car-license-plate-recognition\\doc\\problem\\placas\\040603\\P1010002.jpg"
# img_path = "D:\\projects\\car-license-plate-recognition\\doc\\problem\\placas\\040603\\P6040072.jpg"
# img_path = "D:\\projects\\car-license-plate-recognition\\doc\\problem\\placas\\rus_p001am77.jpg"
# img_path = "D:\\projects\\car-license-plate-recognition\\doc\\problem\\placas\\040603\\P6040066.jpg"

# is not detected
# img_path = "D:\\projects\\car-license-plate-recognition\\doc\\problem\\placas\\040603\\P6040070.jpg"
# img_path = "D:\\projects\\car-license-plate-recognition\\doc\\problem\\placas\\040603\\P6040034.jpg"

coordinates = detect.haar_plate_detection(img_path) 

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

print('PATH\t:', img_path)
print('SIZE\t:', img.shape)
print('COORDS\t:', coordinates)

for (p0, p1, p2, p3) in coordinates:
    img = cv2.line(img, p0, p1, (255,0,0), 1)
    img = cv2.line(img, p1, p2, (255,0,0), 1)
    img = cv2.line(img, p2, p3, (255,0,0), 1)
    img = cv2.line(img, p3, p0, (255,0,0), 1)

plt.figure(figsize=(8, 8))
plt.imshow(img, interpolation='none')
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# PATH	: D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P1010002.jpg
# SIZE	: (480, 640, 3)
# COORDS	: [[(247, 231), (418, 231), (418, 288), (247, 288)], [(232, 222), (455, 222), (455, 296), (232, 296)]]

# %% [markdown]
# ### License Plate Detection using ALPR

# %%
% matplotlib inline

import cv2
import matplotlib.pyplot as plt
from plate import detect

img_path = 'D:\\projects\\car-license-plate-recognition\\doc\\problem\\placas\\040603\\P1010002.jpg'
img_path = "D:\\projects\\car-license-plate-recognition\\doc\\problem\\placas\\040603\\P6040070.jpg"
# img_path = "D:\\projects\\car-license-plate-recognition\\doc\\problem\\placas\\040603\\P6040034.jpg"

coordinates = detect.alpr_plate_detection(img_path) 

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

print('PATH\t:', img_path)
print('SIZE\t:', img.shape)
print('COORDS\t:', coordinates)

for (p0, p1, p2, p3) in coordinates:
    img = cv2.line(img, p0, p1, (255,0,0), 1)
    img = cv2.line(img, p1, p2, (255,0,0), 1)
    img = cv2.line(img, p2, p3, (255,0,0), 1)
    img = cv2.line(img, p3, p0, (255,0,0), 1)

plt.figure(figsize=(8, 8))
plt.imshow(img, interpolation='none')
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# PATH	: D:\projects\car-license-plate-recognition\doc\problem\placas\040603\P6040070.jpg
# SIZE	: (480, 640, 3)
# COORDS	: [[(152, 298), (306, 306), (305, 338), (151, 330)], [(344, 397), (509, 390), (512, 433), (344, 440)]]
